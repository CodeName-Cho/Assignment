# %% [markdown]
# <a href="https://colab.research.google.com/github/CodeName-Cho/Assignment/blob/main/ESAA_Week2_Fri_Summary_HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## ESAA 2주차 월요일 필사 과제
# # 시각화

# %% [markdown]
# ## 시각화를 시작하며 - 맷플롯립과 시본 개요
# ### 맷플롯립
# 가장 많이 쓰임, 직관적이진 못함, 부가적 속성 코딩 필요, 기본
# ### 시본
# 맷플롯립보다 쉽고 판다스와 연동 가능, 맷플롯립 기반

# %% [markdown]
# ## 맷플롯립

# %% [markdown]
# ### 맷플롯립의 pyplot 모듈의 이해
# ### matplotlib.pyplot
# - 맷플롯립 파이썬 시각화 위한 기반 모듈
# - 관용적으로 plt로 임포트
#
# #### - plot()
# 입력값으로 x축,y축 데이터 입력 받아 선그래프 그리기
#
# #### - title()
# 입력값으로 타이틀 문자열을 받아 차트 타이틀 설정
#
# #### - show()
# 선 그래프를 화면에 나타냄

# %%
# pyplot 모듈을 (관용적으로) plt라는 이름으로 import
import matplotlib.pyplot as plt

# x축 입력값[1,2,3], y축 입력값 [2,4,6]으로 선 그래프 생성
plt.plot([1,2,3],[2,4,6])

# 선그래프 타이틀을 Hello plot으로 설정
plt.title("Hello plot")

# 선 그래프를 출력
plt.show()

# %% [markdown]
# ## pyplot의 두 가지 중요 요소 - Figure와 Axes 이해
# ### Figure
# 그림을 그리기 위한 캔버스, 실제 그림을 그리는 메서드는 아님
# ### Axes
# 실제 그림을 그리는 메서드
#
# 시각화를 수행하는 메서드들은 Axes에서 호출
#
# X축, Y축, 타이틀, 범례 등 설정에도 이용
#
# 1) plt.plot([1,2,3],[2,4,6])
#
# -> 기본으로 설정된 Axes에서 Axes.plot() 함수를 호출하여 그림을 그립니다. Axes.plot()은 다시 Line2D 객체를 호출하여 선 그래프를 그립니다.
#
# 2) plt.tilte("Hello plot")
#
# plt.title()은 내부적으로 다시 Axes.set_title() 함수를 호출하여 타이틀을 설정합니다.

# %% [markdown]
# ## figure와 Axis의 활용
# ### Figure(가로크기, 세로크기)
# 주로 전체 그림판 크기 조절에 이용된다.

# %%
# plt.figure()는 주로 figure의 크기를 조절하는 데 사용됨.
# 아래는 figure 크기가 가로 10, 세로 4인 Figure 객체를 설정하고 반환함
plt.figure(figsize=(10,4))

plt.plot([1,2,3],[2,4,6])
plt.title("Hello plot")
plt.show()

# %% [markdown]
# plt의 figure() 함수는 Figure 객체를 반환함

# %%
figure = plt.figure(figsize=(10,4))
print(type(figure))
# Out:
# <class 'matplotlib.figure.Figure'>

# %% [markdown]
# ### facecolor
#
# figure 함수로 그림판 배경 색도 바꿀 수 있다.
#
# 전체 그림판 색이 변하진 않는 게 Axes 차지 영역이 figure 그림판 위에 적용됨

# %%
plt.figure(figsize=(4,4),facecolor="yellow")
plt.plot([1,2,3],[2,4,6])
plt.title("Hello plot")
plt.show()

# %% [markdown]
# plt의 axes() 함수는 현재 사용하는 Axes 객체를 반환
#
# 반환된 객체는 AxesSubplot는 Axes의 실체화된 하위 클래스
#
# plt.axes()만 호출해도 축 포함하는 게 pyplot 임포트 된 채면 plt.show 없어도 Axes 할당돼있으면 자동 plt.show() 역할

# %%
ax = plt.axes()
print(type(ax))
# Out:
# <class 'matplotlib.axes._axes.Axes'>

# %% [markdown]
# ### plt.subplots()
# pyplot에서 Figure와 Axes 객체 함께 가져올 수 있음
#
# 인자로 여러 Axes도 설정 가능

# %%
### pyplot에서 설정된 Figure와 Axes 객체를 함께 가져오기
fig, ax = plt.subplots()
print('fig type:', type(fig), "\nax type:", type(ax))
# Out:
# fig type: <class 'matplotlib.figure.Figure'>
# ax type: <class 'matplotlib.axes._axes.Axes'>

# %% [markdown]
# pyplot의 plot() 이나 title()이 아닌 Axes 객체를 이용해 선그래프 그리기

# %%
fig, ax = plt.subplots(figsize=(4,4))

# Axes 객체의 plot()을 이용하여 선 그래프를 그림
ax.plot([1,2,3],[2,4,6])

# Axes 객체의 set_title()을 이용해 선그래프 타이틀을 Hello plot으로 설정
ax.set_title('Hello plot')
plt.show()

# %% [markdown]
# ### plt.subplots()
# 여러개의 plot을 가지는 subplot 생성함
#
# 개별 subplot은 하나의 Axes를 가지며 1개의 figure와 여러개의 axes를 생성하고 반환함
#
# 주요인자
# - nrows
# - ncols
# - figsize -튜플이나 ndaarray

# %%
# 아래는 두 개의 subplot, 즉 두 개의 Axes를 생성하되, 열 방향으로 두 개를 배치함
# 또한 전체 크기가 가로 6, 세로 3인 figure 생성
fig, (ax1,ax2) = plt.subplots(nrows=1,ncols=2,figsize=(6,3))

# %% [markdown]
# ### pyplot의 plot()
# 선 그래프를 그릴 때 활용
#
# X 좌표값과 Y 좌표 값 개수는 같아야함

# %%
import numpy as np
import pandas as pd

x_value = [1,2,3,4]
y_value = [2,4,6,8]
#x_value = np.array([1,2,3,4]) # 넘파이 array로 테스트 하려면 주석을 해제하고 실행
#y_value = np.array([2,4,6,8]) # 넘파이 arryay로 테스트하려면 주석을 해제하고 실행

# 입력값으로 파이썬 리스트, numpy array 가능. x 좌표값과 y좌표값은 모두 같은 크기를 가져야 함
plt.plot(x_value, y_value)
plt.show()

# %% [markdown]
# ### plot() 함수의 color 인자
# 색상 변결

# %%
# color 인자를 green으로 설정하여 선의 색을 녹색으로 변경
plt.plot(x_value, y_value, color='green')

# %% [markdown]
# 다양한 인자들 예시 결과
#
# 선의 색: 빨강
#
# 선의 형태: 대시
#
# 선의 두께: 2
#
# 각 좌표점별로 동그라미 형태
#
# 마커 크기: 12

# %%
# API 기반으로 시각화를 구현할 때는 함수의 인자들에 대해서 알고 있어야 하는 부작용(?)이 있음
plt.plot(
    x_value, y_value, color='red', marker='o', linestyle='dashed', linewidth=2, markersize=12
)

# %% [markdown]
# API 기반의 시각화는 필연적으로 코드를 이용해 해당 함수들에 대한 인자 값이나 시각화를 위한 여러 가지 주변 값들을 설정해줘야 한다.

# %% [markdown]
# ### 축 명칭 설정, 축 눈금값 회전, 범례 설정
#
# ### xlabel(), ylabel() -> 축의 명칭 설정

# %%
plt.plot(
    x_value, y_value, color='red', marker='o', linestyle='dashed', linewidth=2, markersize=12
)

# x축과 y축의 이름을 텍스트로 할당하여 설정
plt.xlabel('x axies')
plt.ylabel('y axis')
plt.show()

# %% [markdown]
# ### xticks() & yticks()
# 축의 눈금 잘 보이게 회전
#
# x축 회전 : xticks()
# y축 회전 : yticks()

# %%
# x 좌표 값을 0~99까지 100개로 설정
x_value = np.arange(0,100)
# y 좌표 값은 개별 x좌표값을 2배로 해서 100개로 설정
y_value = 2*x_value

plt.plot(x_value, color='green')
plt.xlabel('x axis')
plt.ylabel('y axis')

# x축 눈금값을 90도 회전
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# ### xticks() 함수 인자로 ticks 값 설정
#
# 눈금 간격 조절
#
# 원래는 축 값이 숫자면 최대,최솟값 보고 알잘딱깔센 해주지만 원하면 커스텀 가능

# %%
x_value = np.arange(0,100)
y_value = 2*x_value

plt.plot(x_value, y_value, color='green')
plt.xlabel('x axis')
plt.ylabel('y axis')

# x축의 눈금값을 np.arrange=(0,100,5)로 하여 0부터 5 스텝으로 20개를 표시하고
# x축 눈금값을 90도 회전
plt.xticks(ticks=np.arange(0,100,5),rotation=90)

plt.title('Hello plot')
plt.show()

# %% [markdown]
# ### 범례(legend)
# - plt.plot() 함수 내에 label 인자값 설정해 명칭 부여 후 plt.legend() 호출해 범례를 Axes 상에 나타냄
#
# 여러 개의 그래프/차트를 한 Axes 내에서 구분할 때 사용
#
# 맷플롯립은 여러 개의 플롯을 하나의 Axes 내에서 그릴 수 있다.

# %%
# x 좌표 값을 0~99까지 100개, 첫번째 y좌표값은 x좌표값의 두 배, 두번째 좌표값은
# x 좌표의 4배
x_value_01 = np.arange(0,100)
y_value_01 = 2*x_value_01
y_value_02 = 4*x_value_01

# x좌표값과 첫번째 y좌표값으로 녹색의 선그래프를 그림, label을 'green line'으로 설정
plt.plot(x_value_01, y_value_01, color='green', label='green line')
# x좌표값과 두번째 y좌표값으로 빨간색 선그래프를 그리고 label을 'red line'으로 설정
plt.plot(x_value_01, y_value_02, color='red', label='red plot')

plt.xlabel('x axis')
plt.ylabel('y axis')
# 개별 plot들의 label로 설정된 문자열을 범례로 표시
plt.legend()

plt.title('Hello plot')

plt.show()

# %% [markdown]
# ### bar plot
# 막대 그래프

# %%
x_value_01 = np.arange(0,10)
y_value_01 = 2*x_value_01

# 마커를 포함한 빨간색 대시 선 그래프를 그리고, label은 'red line'으로 설정
plt.plot(x_value_01, y_value_01, color='red', label='red line')
# x값에 따른 y값을 나타내는 초록색 막대 그래프를 그리고 label은 'label'은 'bar plot'으로 설정
plt.plot(x_value_01, y_value_01, color='green', label='bar plot')

plt.xlabel('x axis')
plt.ylabel('y axis')
# 두 개의 그래프에서 label 설정된 문자열 값을 범례로 표시
plt.legend()

plt.title('Hello plot')

plt.show()

# %% [markdown]
# Axes 객체 메서드를 사용해 시각화를 수행
#
# - plt.axes
#
# Axes 객체 추출
#
# - plt.plot()
#
# Axes 객체의 plot()으로
#
# - plt.bar()
#
# Axes 객체의 bar()으로 변경
#
# - set_xlabel() & set_ylabel()
#
# plt.xlabel() & plt.ylabel()
#
# - set_title()
#
# Axes 객체의 plt.title 변경
#
# - legend()
#
# plt.legend() 변경

# %%
figure = plt.figure()
# Axes 객체를 추출하여 ax 변수에 할당
ax = plt.axes()

#plt.plot()은 ax.plot()으로 plt.bar()는 ax.bar()로 변경
ax.plot(x_value_01, y_value_01, color='red', marker='o', linestyle='dashed', label='red line')
ax.bar(x_value_01, y_value_01, color='green', label='bar plot')

# plt.xlabel()은 ax.set_xlabel()로, plt.ylabel()은 ax.set_ylabel()로 변경
ax.set_xlabel('x axis')
ax.set_ylabel('y axis')

# ax.set_legend()가 아니라 ax.legend()임
ax.legend()
#plt.title()을 plt.set_title()로 변경
ax.set_title('Hello plot')

plt.show()

# %% [markdown]
# #### 여러 개의 subplots들을 이용해 개별 그래프들을 subplot별로 시각화하기
#
# 여러 개의 Axes를 이용한 subplots 생성을 아래 예시에서 배열 형태로 받아 시각화함

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(6,3))

# %% [markdown]
# 반환된 Axes 객체들을 가지는 ax 변수는 튜플이 아닌 넘파이 ndarray 형태로 가짐
#
# ax[0] - 왼쪽에 생성된 Axes 객체
#
# ax[1] - 오른쪽에 생성된 Axes 객체

# %%
print('ax type:',type(ax))
print('ax[0] type:', type(ax[0]))
print('ax[1] type:', type(ax[1]))
# Out:
# ax type: <class 'numpy.ndarray'>
# ax[0] type: <class 'matplotlib.axes._axes.Axes'>
# ax[1] type: <class 'matplotlib.axes._axes.Axes'>

# %% [markdown]
# 여러 개의 supplots들 쓰는 경우 개별 Axes 객체를 직접 이용해 시각화 구현해야함

# %%
import numpy as np
x_value_01 = np.arange(1,10)
x_value_02 = np.arange(1,20)
y_value_01 = 2 * x_value_01
y_value_02 = 2 * x_value_02

# figsize는 (6,3)인 Figure와 2개의 Axes를 가지는 subplots을 반환
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(6,3))

# 개별 Axes 객체들을 각각 이용하여 선 그래프와 막대그래프를 그림.
ax[0].plot(x_value_01, y_value_01, color='red', marker='o', linestyle='dashed', label='red line')
ax[1].bar(x_value_02, y_value_02, color='green', label='bar plot')
# 개별 Axes 객체 각각에 x축명을 설정
ax[0].set_xlabel('ax[0] x axis')
ax[1].set_xlabel('ax[1] x axis')
# 개별 Axes 객체 각각에 범례를 설정
ax[0].legend()
ax[1].legend()
# 개별 Axes 객체 각각에 타이틀을 설정
ax[0].set_title('Hello line')
ax[1].set_title('Hello bar')

plt.show()

# %% [markdown]
# plt.subplots()의 인자인 nrows가 1이거나 또는 ncols가 1인 경우에는 1차원 배열 인덱싱 방식으로 Axes을 접근할 수 있습니다.
#
# nrows, ncols 둘다 2 이상이면 2차원 배열 인덱싱 방식으로 접근해야 함

# %%
import numpy as np

x_value_01 = np.arange(1,10)
x_value_02 = np.arange(1,20)
y_value_01 = 2 * x_value_01
y_value_02 = 2 * x_value_02

# figsize는 (6,6)인 Figure와 2x2개의 Axes를 가지는 subplots을 반환
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(6,6))

# 2x2 Axes 객체들을 각각 이용하여 선 그래프와 막대그래프를 그림
ax[0][0].plot(x_value_01, y_value_01, color='red', marker='o', linestyle='dashed', label='red line')
ax[0][1].bar(x_value_02, y_value_02, color='green', label='green bar')
ax[1][0].plot(
    x_value_01, y_value_01, color='green', marker='o', linestyle='dashed', label='green line'
)
ax[1][1].bar(x_value_02, y_value_02, color='red', label='red bar')

# 개별 Axes 객체 각각에 x축명을 설정
ax[0][0].set_xlabel('ax[0][0] x axis')
ax[0][1].set_xlabel('ax[0][1] x axis')
ax[1][0].set_xlabel('ax[1][0] x axis')
ax[1][1].set_xlabel('ax[1][1] x axis')

# 개별 Axes 객체 각각에 범례를 설정
ax[0][0].legend()
ax[0][1].legend()
ax[1][0].legend()
ax[1][1].legend()

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
